# %%
 f = open("새파일.txt",'w')
 for i in range(1,11):
   data = f'{i}번째 줄입니다.\n'
   f.write(data)
 f.close()

# %%
 f = open("새파일.txt",'r')
 line = f.readline()
 print(line)
 f.close()
# Out:
# 1번째 줄입니다.
