# %% [markdown]
# # 파이썬으로 PC 파일 조작

# %%
import os

파일들  = os.listdir('test') # 거기있는 파일명 다 가져와주셈
print(파일들)

# os.rename('test/1.txt','test/4.txt')

for i in os.listdir('test') :
  os.rename(f'test/{i}',f'test/a{i}')
# Out:
# ['2.txt', '.ipynb_checkpoints', '3.txt', '4.txt']

# %% [markdown]
# 파이썬을 이용한 파일 복사

# %%
import shutil
for i in os.listdir('test'):
  if  # 만약에 지금 i 라는 파일명에 jpg가 들어있으면
  shutil.copy(f'test/{i}',f'test2/{i}')

# os.path.join ('경로'+'경로2')  경로 합쳐주는 함수
# os.getcwd() 현재경로 알려주는 함수
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-10-5d2bb79d046e> in <module>()
#       1 import shutil
#       2 for i in os.listdir('test'):
# ----> 3   shutil.copy(f'test/{i}',f'test2/{i}')
#
# /usr/lib/python3.7/shutil.py in copy(src, dst, follow_symlinks)
#     246     if os.path.isdir(dst):
#     247         dst = os.path.join(dst, os.path.basename(src))
# --> 248     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     249     copymode(src, dst, follow_symlinks=follow_symlinks)
#     250     return dst
#
# /usr/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# ...
