# %%
# 회귀분석 liner regression
import numpy as np


키 = np.array([170,180,160,165,158,176,182,172]).reshape((-1,1))

몸무게 = [75,81,59,70,55,78,84,72] 

import matplotlib.pyplot as plt
plt.scatter(키,몸무게)
plt.show()

# 회귀분석 하는 이유
#  1. 데이터칸 비례/반비례 여부 파악가능
# 선을 그린다.-> OLS 를 충족하는 선(최적의 선)

from sklearn.linear_model import LinearRegression

model = LinearRegression().fit(키,몸무게)
print(model.score(키,몸무게)) # 0~1 사이의 R값이 나오는데 1에 가까울수록 연관성이 높음
print(model.intercept_) # y= ax+b 중 b
print(model.coef_)# 중 a

print(model.predict([[170],[180]],)) # 추정

plt.scatter(키,몸무게)
plt.plot(키,model.predict(키))
plt.show()
# Out:
# 0.9361426318808449
# -118.03578708946768
# [1.11392978]
# [71.33227633 82.47157418]

# %%
# 회귀 분석 2

import numpy as np
import statsmodels.api as sm
키 = np.array([170,180,160,165,158,176,182,172]).reshape((-1,1))
몸무게 = np.array([75,81,59,70,55,78,84,72]) 

model = sm.OLS(몸무게,키).fit() # (y,x)
print(model.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.993
# Model:                            OLS   Adj. R-squared (uncentered):              0.992
# Method:                 Least Squares   F-statistic:                              936.5
# Date:                Mon, 24 May 2021   Prob (F-statistic):                    1.03e-08
# Time:                        02:03:57   Log-Likelihood:                         -25.993
# No. Observations:                   8   AIC:                                      53.99
# Df Residuals:                       7   BIC:                                      54.06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
import numpy as np
import statsmodels.api as sm
import pandas as pd

df = pd.read_csv('california_housing.csv')

model = sm.OLS(df['price'],df[['year', 'rooms','bedrooms']]).fit()
print(model.summary())
print(model.predict([[20,1000,200]]))
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.751
# Model:                            OLS   Adj. R-squared (uncentered):              0.751
# Method:                 Least Squares   F-statistic:                          1.710e+04
# Date:                Mon, 24 May 2021   Prob (F-statistic):                        0.00
# Time:                        02:17:49   Log-Likelihood:                     -2.2273e+05
# No. Observations:               17000   AIC:                                  4.455e+05
# Df Residuals:                   16997   BIC:                                  4.455e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
